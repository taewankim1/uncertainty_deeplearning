# %%
import os
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
sns.set(style='darkgrid')
from copy import deepcopy
from torchvision import transforms
def print_np(x):
    print('(1) Type is %s' %(type(x)))
    print('(2) Shape is %s' %(x.shape,))
#     print('(3) Values are : \n%s' %(x))

# %%
from gpr import kernel_se, gpr

# %% [markdown]
# ## data generation

# %%
# data (no noise)
x_data = np.linspace(-8,8,200).reshape((-1,1))
y_data = np.cos(np.pi/2*x_data)*np.exp(-(x_data/4)**2) 
# train (add noise)
# N_train = 50
x_train = np.vstack((np.linspace(-6,-2.5,90).reshape((-1,1)),np.linspace(-1.5,6,150).reshape((-1,1)) ))
y_train = np.cos(np.pi/2*x_train)*np.exp(-(x_train/4)**2) + 0.1*np.random.randn(*np.shape(x_train))
y_train += 0.5*np.random.randn(*np.shape(x_train)) * np.logical_and(x_train > 1,x_train < 3)

def plot_vline() :
    alpha = 0.3
    plt.vlines(-6, -2, 2, colors='k', linestyles='--',alpha=alpha)
    plt.vlines(-2.5, -2, 2, colors='k', linestyles='--',alpha=alpha)
    plt.vlines(-1.5, -2, 2, colors='k', linestyles='--',alpha=alpha)
    plt.vlines(1, -2, 2, colors='k', linestyles='--',alpha=alpha)
    plt.vlines(3, -2, 2, colors='k', linestyles='--',alpha=alpha)
    plt.vlines(6, -2, 2, colors='k', linestyles='--',alpha=alpha)
    
    plt.text(-7.8, -1.5, 'epistemic',fontsize=15,color='g')
    plt.text(-2.7, -1.5, 'epistemic',fontsize=15,color='g')
    plt.text(6.1, -1.5, 'epistemic',fontsize=15,color='g')
    plt.text(1.1, -1.5, 'Heteroscedastic',fontsize=15,color='g')
    plt.text(1.1, -1.7, 'aleatoric',fontsize=15,color='g')
    
plt.figure(figsize=(12,6))
plt.axis([-8,8,-2.0,2.0])
plt.plot(x_data,y_data,label='True',color='k')
plt.plot(x_train,y_train,'r.',label='train')

plot_vline()
plt.grid(True)
plt.legend(fontsize=16)
plt.title('Training Data for a Regression Task',fontsize=16)

# %% [markdown]
# ## Gaussian process regression

# %%
# Do inference
hyp={'gain':5,'len':1./1.,'s2w':1e-2*5}
GPR = gpr(_xTr=x_train,_yTr=y_train,_hyp=hyp)
y_pred, y_sigma_pred = GPR.inference(_xTe=x_data)
y_sigma_pred = y_sigma_pred.reshape((-1,1))

# %%
plt.figure(figsize=(12,6))
plt.axis([-8,8,-2.0,2.0])
plt.plot(x_data,y_data,label='True',color='k')
plt.plot(x_train,y_train,'r.',label='train')
plt.plot(x_data,y_pred,'b',label='pred')
plt.fill_between(x_data[:,0],y_pred[:,0]+y_sigma_pred[:,0],
                 y_pred[:,0]-y_sigma_pred[:,0],color='b',alpha=.25,label='1 sigma')

plot_vline()
plt.grid(True)
plt.legend(fontsize=16)
plt.title('Training Data for a Regression Task',fontsize=16)

plt.figure(figsize=(12,6))
plt.axis([-7.5,7.5,0.0,1.0])
plt.plot(x_data,y_sigma_pred,'b',label='1 sigma')
plt.legend(fontsize=16)

# %% [markdown]
# # Neural Net

# %%
import torch
from datasetter import SimpleDataset
from transformer import FloatToTensor
from trainer import RegressionTrainer
from models import LinearNN
import torch.optim as optim
from torch.optim import lr_scheduler
from torch import nn

# %%
transform = transforms.Compose([
            FloatToTensor(),
        ])

# %%
# TODO : normalization

# %%
datasets = {}
datasets['train'] = SimpleDataset(x_train,y_train,np.shape(x_train)[0],transform)
datasets['valid'] = SimpleDataset(x_data,y_data,np.shape(x_data)[0],transform)

# %%
dataloaders = {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],batch_size=128,shuffle=True)
dataloaders['valid'] = torch.utils.data.DataLoader(datasets['valid'],batch_size=len(x_train),shuffle=True)

# %%
num_hidden = 100
model = LinearNN(num_hidden,drop_prob=0.2)
print(model)
optimizer = optim.Adam(model.parameters(),lr=0.01)
criterion = nn.MSELoss()
scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
# Out:
# LinearNN(
#   (fc1): Linear(in_features=1, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.2, inplace=False)
# )

# %%
LinearNN_trainer = RegressionTrainer('hello')

# %%
LinearNN_trainer.train_model(model,criterion,optimizer,scheduler,500,dataloaders,False)
# Out:
# Epoch 0/499
# ----------
# train loss is 0.0059
# valid loss is 0.0076
#
# Epoch 1/499
# ----------
# train loss is 0.0064
# valid loss is 0.0039
#
# Epoch 2/499
# ----------
# train loss is 0.0059
# valid loss is 0.0020
#
# Epoch 3/499
# ----------
# train loss is 0.0026
# valid loss is 0.0011
#
# Epoch 4/499
# ----------
# train loss is 0.0023
# valid loss is 0.0015
#
# Epoch 5/499
# ----------
# train loss is 0.0024
# valid loss is 0.0013
#
# Epoch 6/499
# ----------
# train loss is 0.0022
# valid loss is 0.0009
#
# Epoch 7/499
# ----------
# train loss is 0.0020
# valid loss is 0.0008
#
# Epoch 8/499
# ----------
# train loss is 0.0019
# valid loss is 0.0008
#
# Epoch 9/499
# ----------
# train loss is 0.0019
# valid loss is 0.0008
#
# Epoch 10/499
# ----------
# train loss is 0.0018
# valid loss is 0.0008
#
# Epoch 11/499
# ----------
# train loss is 0.0018
# valid loss is 0.0007
#
# Epoch 12/499
# ----------
# train loss is 0.0017
# valid loss is 0.0007
#
# Epoch 13/499
# ----------
# train loss is 0.0017
# valid loss is 0.0007
#
# Epoch 14/499
# ----------
# train loss is 0.0016
# valid loss is 0.0007
#
# Epoch 15/499
# ----------
# train loss is 0.0015
# valid loss is 0.0007
#
# Epoch 16/499
# ----------
# train loss is 0.0015
# valid loss is 0.0006
#
# Epoch 17/499
# ----------
# train loss is 0.0014
# valid loss is 0.0006
#
# Epoch 18/499
# ----------
# train loss is 0.0014
# valid loss is 0.0006
#
# Epoch 19/499
# ----------
# train loss is 0.0014
# valid loss is 0.0005
#
# Epoch 20/499
# ----------
# train loss is 0.0013
# valid loss is 0.0005
#
# Epoch 21/499
# ----------
# train loss is 0.0013
# valid loss is 0.0005
#
# Epoch 22/499
# ----------
# train loss is 0.0013
# valid loss is 0.0005
#
# Epoch 23/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 24/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 25/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 26/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 27/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 28/499
# ----------
# train loss is 0.0012
# valid loss is 0.0005
#
# Epoch 29/499
# ----------
# train loss is 0.0011
# valid loss is 0.0005
#
# Epoch 30/499
# ----------
# train loss is 0.0011
# valid loss is 0.0005
#
# Epoch 31/499
# ----------
# train loss is 0.0011
# valid loss is 0.0005
#
# Epoch 32/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 33/499
# ----------
# train loss is 0.0011
# valid loss is 0.0005
#
# Epoch 34/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 35/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 36/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 37/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 38/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 39/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 40/499
# ----------
# train loss is 0.0010
# valid loss is 0.0004
#
# Epoch 41/499
# ----------
# train loss is 0.0010
# valid loss is 0.0005
#
# Epoch 42/499
# ----------
# train loss is 0.0009
# valid loss is 0.0005
#
# Epoch 43/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 44/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 45/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 46/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 47/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 48/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 49/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 50/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 51/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 52/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 53/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 54/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 55/499
# ----------
# train loss is 0.0008
# valid loss is 0.0003
#
# Epoch 56/499
# ----------
# train loss is 0.0008
# valid loss is 0.0003
#
# Epoch 57/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 58/499
# ----------
# train loss is 0.0009
# valid loss is 0.0004
#
# Epoch 59/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 60/499
# ----------
# train loss is 0.0008
# valid loss is 0.0004
#
# Epoch 61/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 62/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 63/499
# ----------
# train loss is 0.0008
# valid loss is 0.0003
#
# Epoch 64/499
# ----------
# train loss is 0.0007
# valid loss is 0.0004
#
# Epoch 65/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 66/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 67/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 68/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 69/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 70/499
# ----------
# train loss is 0.0007
# valid loss is 0.0004
#
# Epoch 71/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 72/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 73/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 74/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 75/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 76/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 77/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 78/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 79/499
# ----------
# train loss is 0.0008
# valid loss is 0.0003
#
# Epoch 80/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 81/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 82/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 83/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 84/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 85/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 86/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 87/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 88/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 89/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 90/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 91/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 92/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 93/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 94/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 95/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 96/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 97/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 98/499
# ----------
# train loss is 0.0007
# valid loss is 0.0003
#
# Epoch 99/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 100/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 101/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 102/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 103/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 104/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 105/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 106/499
# ----------
# train loss is 0.0006
# valid loss is 0.0004
#
# Epoch 107/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 108/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 109/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 110/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 111/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 112/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 113/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 114/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 115/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 116/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 117/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 118/499
# ----------
# train loss is 0.0006
# valid loss is 0.0004
#
# Epoch 119/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 120/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 121/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 122/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 123/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 124/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 125/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 126/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 127/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 128/499
# ----------
# train loss is 0.0005
# valid loss is 0.0004
#
# Epoch 129/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 130/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 131/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 132/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 133/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 134/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 135/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 136/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 137/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 138/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 139/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 140/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 141/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 142/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 143/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 144/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 145/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 146/499
# ----------
# train loss is 0.0006
# valid loss is 0.0004
#
# Epoch 147/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 148/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 149/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 150/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 151/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 152/499
# ----------
# train loss is 0.0005
# valid loss is 0.0004
#
# Epoch 153/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 154/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 155/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 156/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 157/499
# ----------
# train loss is 0.0005
# valid loss is 0.0004
#
# Epoch 158/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 159/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 160/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 161/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 162/499
# ----------
# train loss is 0.0006
# valid loss is 0.0002
#
# Epoch 163/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 164/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 165/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 166/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 167/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 168/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 169/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 170/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 171/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 172/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 173/499
# ----------
# train loss is 0.0006
# valid loss is 0.0002
#
# Epoch 174/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 175/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 176/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 177/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 178/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 179/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 180/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 181/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 182/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 183/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 184/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 185/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 186/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 187/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 188/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 189/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 190/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 191/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 192/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 193/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 194/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 195/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 196/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 197/499
# ----------
# train loss is 0.0006
# valid loss is 0.0003
#
# Epoch 198/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 199/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 200/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 201/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 202/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 203/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 204/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 205/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 206/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 207/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 208/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 209/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 210/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 211/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 212/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 213/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 214/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 215/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 216/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 217/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 218/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 219/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 220/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 221/499
# ----------
# train loss is 0.0004
# valid loss is 0.0003
#
# Epoch 222/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 223/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 224/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 225/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 226/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 227/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 228/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 229/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 230/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 231/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 232/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 233/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 234/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 235/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 236/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 237/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 238/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 239/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 240/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 241/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 242/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 243/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 244/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 245/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 246/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 247/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 248/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 249/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 250/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 251/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 252/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 253/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 254/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 255/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 256/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 257/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 258/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 259/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 260/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 261/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 262/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 263/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 264/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 265/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 266/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 267/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 268/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 269/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 270/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 271/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 272/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 273/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 274/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 275/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 276/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 277/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 278/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 279/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 280/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 281/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 282/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 283/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 284/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 285/499
# ----------
# train loss is 0.0005
# valid loss is 0.0003
#
# Epoch 286/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 287/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 288/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 289/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 290/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 291/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 292/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 293/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 294/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 295/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 296/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 297/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 298/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 299/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 300/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 301/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 302/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 303/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 304/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 305/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 306/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 307/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 308/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 309/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 310/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 311/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 312/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 313/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 314/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 315/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 316/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 317/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 318/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 319/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 320/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 321/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 322/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 323/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 324/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 325/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 326/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 327/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 328/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 329/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 330/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 331/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 332/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 333/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 334/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 335/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 336/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 337/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 338/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 339/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 340/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 341/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 342/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 343/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 344/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 345/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 346/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 347/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 348/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 349/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 350/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 351/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 352/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 353/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 354/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 355/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 356/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 357/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 358/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 359/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 360/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 361/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 362/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 363/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 364/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 365/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 366/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 367/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 368/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 369/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 370/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 371/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 372/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 373/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 374/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 375/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 376/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 377/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 378/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 379/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 380/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 381/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 382/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 383/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 384/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 385/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 386/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 387/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 388/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 389/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 390/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 391/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 392/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 393/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 394/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 395/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 396/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 397/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 398/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 399/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 400/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 401/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 402/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 403/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 404/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 405/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 406/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 407/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 408/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 409/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 410/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 411/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 412/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 413/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 414/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 415/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 416/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 417/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 418/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 419/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 420/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 421/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 422/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 423/499
# ----------
# train loss is 0.0003
# valid loss is 0.0001
#
# Epoch 424/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 425/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 426/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 427/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 428/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 429/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 430/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 431/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 432/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 433/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 434/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 435/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 436/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 437/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 438/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 439/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 440/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 441/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 442/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 443/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 444/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 445/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 446/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 447/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 448/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 449/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 450/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 451/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 452/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 453/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 454/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 455/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 456/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 457/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 458/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 459/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 460/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 461/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 462/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 463/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 464/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 465/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 466/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 467/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 468/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 469/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 470/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 471/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 472/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 473/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 474/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 475/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 476/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 477/499
# ----------
# train loss is 0.0003
# valid loss is 0.0002
#
# Epoch 478/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 479/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 480/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 481/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 482/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 483/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 484/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 485/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 486/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 487/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 488/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 489/499
# ----------
# train loss is 0.0005
# valid loss is 0.0002
#
# Epoch 490/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 491/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 492/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 493/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 494/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 495/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 496/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 497/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Epoch 498/499
# ----------
# train loss is 0.0004
# valid loss is 0.0001
#
# Epoch 499/499
# ----------
# train loss is 0.0004
# valid loss is 0.0002
#
# Training complete in 0m 6s
# Best loss: 0.000128
# LinearNN(
#   (fc1): Linear(in_features=1, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
y_pred = model(torch.from_numpy(x_data).float()).detach().numpy()

# %%
plt.figure(figsize=(12,6))
plt.axis([-8,8,-2.0,2.0])
plt.plot(x_data,y_data,label='test',color='k')
plt.plot(x_train,y_train,'r.',label='train')
plt.plot(x_data,y_pred,'b',label='pred')
plot_vline()
plt.grid(True)
plt.legend(fontsize=16)
plt.title('Training Data for a Regression Task',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Training Data for a Regression Task')

# %% [markdown]
# # Bayesian NN by dropout

# %%
def apply_dropout(m):
    if type(m) == nn.Dropout:
        m.train()
model.eval()
model.apply(apply_dropout)
# Out:
# LinearNN(
#   (fc1): Linear(in_features=1, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.2, inplace=False)
# )

# %%
N_samples = 20
y_pred_list = np.zeros((len(x_data),N_samples))
for i in range(N_samples) :
    y_pred_list[:,i] = np.squeeze(model(torch.from_numpy(x_data).float()).detach().numpy())
print_np(y_pred_list)
# Out:
# (1) Type is <class 'numpy.ndarray'>
# (2) Shape is (200, 20)

# %%
y_pred_mean = np.mean(y_pred_list,axis=1)
y_pred_sigma = np.sqrt(np.var(y_pred_list,axis=1))
y_pred_mean = np.expand_dims(y_pred_mean,1)
y_pred_sigma = np.expand_dims(y_pred_sigma,1)
print_np(y_pred_sigma)
# Out:
# (1) Type is <class 'numpy.ndarray'>
# (2) Shape is (200, 1)

# %%
plt.figure(figsize=(12,6))
plt.axis([-8,8,-2.0,2.0])
plt.plot(x_data,y_data,label='True',color='k')
plt.plot(x_train,y_train,'r.',label='train')
plt.plot(x_data,y_pred_mean,'b',label='pred')
plt.fill_between(x_data[:,0],y_pred_mean[:,0]+y_pred_sigma[:,0],
                 y_pred_mean[:,0]-y_pred_sigma[:,0],color='b',alpha=.25,label='1 sigma')
plot_vline()
plt.grid(True)
plt.legend(fontsize=16)
plt.title('Training Data for a Regression Task',fontsize=16)

plt.figure(figsize=(12,6))
plt.axis([-8,8,0.0,1.0])
plt.plot(x_data,y_pred_sigma,'b',label='pred')

# %% [markdown]
# # Density network for aleatoric uncertainty

# %%
import torch
from datasetter import SimpleDataset
from transformer import FloatToTensor
from trainer import RegDensityTrainer
from models import LinearDensityNN
from utils import mdn_loss
import torch.optim as optim
from torch.optim import lr_scheduler
from torch import nn

# %%
datasets = {}
datasets['train'] = SimpleDataset(x_train,y_train,np.shape(x_train)[0],transform)
datasets['valid'] = SimpleDataset(x_data,y_data,np.shape(x_data)[0],transform)

# %%
dataloaders = {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],batch_size=32,shuffle=True)
dataloaders['valid'] = torch.utils.data.DataLoader(datasets['valid'],batch_size=len(x_train),shuffle=True)

# %%
num_hidden = 50
model = LinearDensityNN(num_hidden,drop_prob=0.0)
print(model)
optimizer = optim.Adam(model.parameters(),lr=0.001)
criterion = None
scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
# Out:
# LinearDensityNN(
#   (fc1): Linear(in_features=1, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=50, bias=True)
#   (fc3_1): Linear(in_features=50, out_features=1, bias=True)
#   (fc3_2): Linear(in_features=50, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
# )

# %%
DensityNN_trainer = RegDensityTrainer('hello')

# %%
DensityNN_trainer.train_model(model,criterion,optimizer,scheduler,500,dataloaders,False)
# Out:
# Epoch 0/499
# ----------
# train loss is -0.0008
# valid loss is -0.3303
#
# Epoch 1/499
# ----------
# train loss is -0.2897
# valid loss is -0.7960
#
# Epoch 2/499
# ----------
# train loss is -0.4530
# valid loss is -0.8760
#
# Epoch 3/499
# ----------
# train loss is -0.5086
# valid loss is -0.9021
#
# Epoch 4/499
# ----------
# train loss is -0.5100
# valid loss is -0.9320
#
# Epoch 5/499
# ----------
# train loss is -0.5202
# valid loss is -0.9136
#
# Epoch 6/499
# ----------
# train loss is -0.5257
# valid loss is -0.9145
#
# Epoch 7/499
# ----------
# train loss is -0.5336
# valid loss is -0.9053
#
# Epoch 8/499
# ----------
# train loss is -0.5255
# valid loss is -0.9343
#
# Epoch 9/499
# ----------
# train loss is -0.5473
# valid loss is -0.9347
#
# Epoch 10/499
# ----------
# train loss is -0.5424
# valid loss is -0.9388
#
# Epoch 11/499
# ----------
# train loss is -0.5319
# valid loss is -0.8793
#
# Epoch 12/499
# ----------
# train loss is -0.5342
# valid loss is -0.9181
#
# Epoch 13/499
# ----------
# train loss is -0.5515
# valid loss is -0.9318
#
# Epoch 14/499
# ----------
# train loss is -0.5741
# valid loss is -0.9171
#
# Epoch 15/499
# ----------
# train loss is -0.5748
# valid loss is -0.9546
#
# Epoch 16/499
# ----------
# train loss is -0.5843
# valid loss is -0.8832
#
# Epoch 17/499
# ----------
# train loss is -0.5845
# valid loss is -0.9522
#
# Epoch 18/499
# ----------
# train loss is -0.5667
# valid loss is -0.8923
#
# Epoch 19/499
# ----------
# train loss is -0.5595
# valid loss is -0.9220
#
# Epoch 20/499
# ----------
# train loss is -0.5970
# valid loss is -0.9369
#
# Epoch 21/499
# ----------
# train loss is -0.6030
# valid loss is -0.8453
#
# Epoch 22/499
# ----------
# train loss is -0.5876
# valid loss is -0.9324
#
# Epoch 23/499
# ----------
# train loss is -0.6139
# valid loss is -0.7372
#
# Epoch 24/499
# ----------
# train loss is -0.6141
# valid loss is -0.8661
#
# Epoch 25/499
# ----------
# train loss is -0.6201
# valid loss is -0.8810
#
# Epoch 26/499
# ----------
# train loss is -0.6182
# valid loss is -0.9168
#
# Epoch 27/499
# ----------
# train loss is -0.6450
# valid loss is -0.7516
#
# Epoch 28/499
# ----------
# train loss is -0.6529
# valid loss is -0.8689
#
# Epoch 29/499
# ----------
# train loss is -0.6453
# valid loss is -0.8615
#
# Epoch 30/499
# ----------
# train loss is -0.6594
# valid loss is -0.9156
#
# Epoch 31/499
# ----------
# train loss is -0.6666
# valid loss is -0.6557
#
# Epoch 32/499
# ----------
# train loss is -0.6591
# valid loss is -0.7522
#
# Epoch 33/499
# ----------
# train loss is -0.6753
# valid loss is -0.9165
#
# Epoch 34/499
# ----------
# train loss is -0.6951
# valid loss is -0.9425
#
# Epoch 35/499
# ----------
# train loss is -0.7074
# valid loss is -0.9798
#
# Epoch 36/499
# ----------
# train loss is -0.7167
# valid loss is -0.9751
#
# Epoch 37/499
# ----------
# train loss is -0.7236
# valid loss is -0.9858
#
# Epoch 38/499
# ----------
# train loss is -0.7375
# valid loss is -0.9806
#
# Epoch 39/499
# ----------
# train loss is -0.7342
# valid loss is -0.9544
#
# Epoch 40/499
# ----------
# train loss is -0.7247
# valid loss is -0.8505
#
# Epoch 41/499
# ----------
# train loss is -0.7396
# valid loss is -1.0013
#
# Epoch 42/499
# ----------
# train loss is -0.7519
# valid loss is -0.9431
#
# Epoch 43/499
# ----------
# train loss is -0.7713
# valid loss is -1.0500
#
# Epoch 44/499
# ----------
# train loss is -0.7859
# valid loss is -0.9868
#
# Epoch 45/499
# ----------
# train loss is -0.7578
# valid loss is -0.9201
#
# Epoch 46/499
# ----------
# train loss is -0.7356
# valid loss is -0.9225
#
# Epoch 47/499
# ----------
# train loss is -0.7611
# valid loss is -0.8972
#
# Epoch 48/499
# ----------
# train loss is -0.8004
# valid loss is -1.0629
#
# Epoch 49/499
# ----------
# train loss is -0.8156
# valid loss is -0.8959
#
# Epoch 50/499
# ----------
# train loss is -0.8148
# valid loss is -1.0713
#
# Epoch 51/499
# ----------
# train loss is -0.8084
# valid loss is -0.9416
#
# Epoch 52/499
# ----------
# train loss is -0.8283
# valid loss is -1.0525
#
# Epoch 53/499
# ----------
# train loss is -0.8473
# valid loss is -1.0541
#
# Epoch 54/499
# ----------
# train loss is -0.8532
# valid loss is -1.0905
#
# Epoch 55/499
# ----------
# train loss is -0.8413
# valid loss is -0.9291
#
# Epoch 56/499
# ----------
# train loss is -0.8476
# valid loss is -1.0758
#
# Epoch 57/499
# ----------
# train loss is -0.8681
# valid loss is -0.9905
#
# Epoch 58/499
# ----------
# train loss is -0.8518
# valid loss is -1.0913
#
# Epoch 59/499
# ----------
# train loss is -0.8581
# valid loss is -1.0439
#
# Epoch 60/499
# ----------
# train loss is -0.8564
# valid loss is -1.0744
#
# Epoch 61/499
# ----------
# train loss is -0.8702
# valid loss is -1.1357
#
# Epoch 62/499
# ----------
# train loss is -0.8617
# valid loss is -1.0868
#
# Epoch 63/499
# ----------
# train loss is -0.8732
# valid loss is -1.0970
#
# Epoch 64/499
# ----------
# train loss is -0.8768
# valid loss is -1.0931
#
# Epoch 65/499
# ----------
# train loss is -0.8786
# valid loss is -1.0525
#
# Epoch 66/499
# ----------
# train loss is -0.8777
# valid loss is -1.1590
#
# Epoch 67/499
# ----------
# train loss is -0.8806
# valid loss is -1.0846
#
# Epoch 68/499
# ----------
# train loss is -0.8836
# valid loss is -0.9838
#
# Epoch 69/499
# ----------
# train loss is -0.8903
# valid loss is -1.1471
#
# Epoch 70/499
# ----------
# train loss is -0.8807
# valid loss is -1.1572
#
# Epoch 71/499
# ----------
# train loss is -0.8927
# valid loss is -0.8668
#
# Epoch 72/499
# ----------
# train loss is -0.8706
# valid loss is -1.0750
#
# Epoch 73/499
# ----------
# train loss is -0.8836
# valid loss is -1.0741
#
# Epoch 74/499
# ----------
# train loss is -0.8843
# valid loss is -1.1199
#
# Epoch 75/499
# ----------
# train loss is -0.8875
# valid loss is -1.0102
#
# Epoch 76/499
# ----------
# train loss is -0.8919
# valid loss is -1.1191
#
# Epoch 77/499
# ----------
# train loss is -0.8876
# valid loss is -1.1306
#
# Epoch 78/499
# ----------
# train loss is -0.8792
# valid loss is -1.1200
#
# Epoch 79/499
# ----------
# train loss is -0.8590
# valid loss is -0.8428
#
# Epoch 80/499
# ----------
# train loss is -0.9049
# valid loss is -1.1759
#
# Epoch 81/499
# ----------
# train loss is -0.8836
# valid loss is -1.0549
#
# Epoch 82/499
# ----------
# train loss is -0.9058
# valid loss is -1.1637
#
# Epoch 83/499
# ----------
# train loss is -0.9081
# valid loss is -0.9655
#
# Epoch 84/499
# ----------
# train loss is -0.9134
# valid loss is -1.1942
#
# Epoch 85/499
# ----------
# train loss is -0.9083
# valid loss is -0.6009
#
# Epoch 86/499
# ----------
# train loss is -0.8682
# valid loss is -1.0814
#
# Epoch 87/499
# ----------
# train loss is -0.8408
# valid loss is -1.0684
#
# Epoch 88/499
# ----------
# train loss is -0.8614
# valid loss is -0.9904
#
# Epoch 89/499
# ----------
# train loss is -0.8812
# valid loss is -1.1619
#
# Epoch 90/499
# ----------
# train loss is -0.8867
# valid loss is -0.9219
#
# Epoch 91/499
# ----------
# train loss is -0.9134
# valid loss is -1.1993
#
# Epoch 92/499
# ----------
# train loss is -0.9026
# valid loss is -0.9998
#
# Epoch 93/499
# ----------
# train loss is -0.9053
# valid loss is -1.2035
#
# Epoch 94/499
# ----------
# train loss is -0.9164
# valid loss is -0.9626
#
# Epoch 95/499
# ----------
# train loss is -0.9066
# valid loss is -1.2025
#
# Epoch 96/499
# ----------
# train loss is -0.9222
# valid loss is -1.1263
#
# Epoch 97/499
# ----------
# train loss is -0.9214
# valid loss is -1.2205
#
# Epoch 98/499
# ----------
# train loss is -0.9193
# valid loss is -1.1595
#
# Epoch 99/499
# ----------
# train loss is -0.9317
# valid loss is -1.1977
#
# Epoch 100/499
# ----------
# train loss is -0.9284
# valid loss is -1.0784
#
# Epoch 101/499
# ----------
# train loss is -0.9178
# valid loss is -1.1709
#
# Epoch 102/499
# ----------
# train loss is -0.9373
# valid loss is -1.1180
#
# Epoch 103/499
# ----------
# train loss is -0.9325
# valid loss is -1.1843
#
# Epoch 104/499
# ----------
# train loss is -0.9345
# valid loss is -1.1078
#
# Epoch 105/499
# ----------
# train loss is -0.9423
# valid loss is -1.1302
#
# Epoch 106/499
# ----------
# train loss is -0.9201
# valid loss is -1.1123
#
# Epoch 107/499
# ----------
# train loss is -0.9249
# valid loss is -1.1427
#
# Epoch 108/499
# ----------
# train loss is -0.9498
# valid loss is -1.1885
#
# Epoch 109/499
# ----------
# train loss is -0.9284
# valid loss is -1.1221
#
# Epoch 110/499
# ----------
# train loss is -0.9243
# valid loss is -1.1540
#
# Epoch 111/499
# ----------
# train loss is -0.9325
# valid loss is -0.9478
#
# Epoch 112/499
# ----------
# train loss is -0.9331
# valid loss is -1.1124
#
# Epoch 113/499
# ----------
# train loss is -0.9310
# valid loss is -0.9557
#
# Epoch 114/499
# ----------
# train loss is -0.9536
# valid loss is -1.1478
#
# Epoch 115/499
# ----------
# train loss is -0.9009
# valid loss is -1.0516
#
# Epoch 116/499
# ----------
# train loss is -0.9293
# valid loss is -1.0223
#
# Epoch 117/499
# ----------
# train loss is -0.9755
# valid loss is -1.2721
#
# Epoch 118/499
# ----------
# train loss is -0.9411
# valid loss is -0.8126
#
# Epoch 119/499
# ----------
# train loss is -0.9381
# valid loss is -1.1961
#
# Epoch 120/499
# ----------
# train loss is -0.9513
# valid loss is -1.1357
#
# Epoch 121/499
# ----------
# train loss is -0.9644
# valid loss is -1.2739
#
# Epoch 122/499
# ----------
# train loss is -0.9586
# valid loss is -1.2432
#
# Epoch 123/499
# ----------
# train loss is -0.9650
# valid loss is -1.1482
#
# Epoch 124/499
# ----------
# train loss is -0.9596
# valid loss is -1.2080
#
# Epoch 125/499
# ----------
# train loss is -0.9584
# valid loss is -1.0830
#
# Epoch 126/499
# ----------
# train loss is -0.9268
# valid loss is -1.2386
#
# Epoch 127/499
# ----------
# train loss is -0.9658
# valid loss is -1.1202
#
# Epoch 128/499
# ----------
# train loss is -0.9815
# valid loss is -1.1967
#
# Epoch 129/499
# ----------
# train loss is -0.9727
# valid loss is -1.0289
#
# Epoch 130/499
# ----------
# train loss is -0.9896
# valid loss is -1.2230
#
# Epoch 131/499
# ----------
# train loss is -0.9881
# valid loss is -1.0424
#
# Epoch 132/499
# ----------
# train loss is -0.9838
# valid loss is -1.2837
#
# Epoch 133/499
# ----------
# train loss is -0.9669
# valid loss is -0.9732
#
# Epoch 134/499
# ----------
# train loss is -0.9849
# valid loss is -1.2547
#
# Epoch 135/499
# ----------
# train loss is -0.9617
# valid loss is -1.0307
#
# Epoch 136/499
# ----------
# train loss is -0.9825
# valid loss is -1.2028
#
# Epoch 137/499
# ----------
# train loss is -1.0073
# valid loss is -1.1244
#
# Epoch 138/499
# ----------
# train loss is -0.9887
# valid loss is -1.0244
#
# Epoch 139/499
# ----------
# train loss is -0.9942
# valid loss is -1.2711
#
# Epoch 140/499
# ----------
# train loss is -1.0146
# valid loss is -0.8450
#
# Epoch 141/499
# ----------
# train loss is -1.0020
# valid loss is -1.3022
#
# Epoch 142/499
# ----------
# train loss is -0.9983
# valid loss is -0.9080
#
# Epoch 143/499
# ----------
# train loss is -0.9815
# valid loss is -0.9395
#
# Epoch 144/499
# ----------
# train loss is -0.9932
# valid loss is -1.1382
#
# Epoch 145/499
# ----------
# train loss is -1.0117
# valid loss is -1.0633
#
# Epoch 146/499
# ----------
# train loss is -1.0244
# valid loss is -1.0537
#
# Epoch 147/499
# ----------
# train loss is -1.0130
# valid loss is -1.2728
#
# Epoch 148/499
# ----------
# train loss is -1.0317
# valid loss is -1.1252
#
# Epoch 149/499
# ----------
# train loss is -1.0085
# valid loss is -0.7967
#
# Epoch 150/499
# ----------
# train loss is -1.0095
# valid loss is -1.2657
#
# Epoch 151/499
# ----------
# train loss is -0.9856
# valid loss is -1.0961
#
# Epoch 152/499
# ----------
# train loss is -1.0037
# valid loss is -1.0832
#
# Epoch 153/499
# ----------
# train loss is -1.0246
# valid loss is -0.8225
#
# Epoch 154/499
# ----------
# train loss is -1.0411
# valid loss is -0.9326
#
# Epoch 155/499
# ----------
# train loss is -1.0448
# valid loss is -1.3028
#
# Epoch 156/499
# ----------
# train loss is -1.0341
# valid loss is -1.0744
#
# Epoch 157/499
# ----------
# train loss is -1.0522
# valid loss is -1.1935
#
# Epoch 158/499
# ----------
# train loss is -1.0402
# valid loss is -1.0349
#
# Epoch 159/499
# ----------
# train loss is -1.0471
# valid loss is -1.1608
#
# Epoch 160/499
# ----------
# train loss is -1.0133
# valid loss is -0.5958
#
# Epoch 161/499
# ----------
# train loss is -1.0512
# valid loss is -1.1556
#
# Epoch 162/499
# ----------
# train loss is -1.0231
# valid loss is -0.8820
#
# Epoch 163/499
# ----------
# train loss is -1.0069
# valid loss is -0.6626
#
# Epoch 164/499
# ----------
# train loss is -1.0122
# valid loss is -1.2216
#
# Epoch 165/499
# ----------
# train loss is -1.0130
# valid loss is -0.7898
#
# Epoch 166/499
# ----------
# train loss is -1.0302
# valid loss is -0.8418
#
# Epoch 167/499
# ----------
# train loss is -1.0280
# valid loss is -0.9977
#
# Epoch 168/499
# ----------
# train loss is -1.0240
# valid loss is -0.8980
#
# Epoch 169/499
# ----------
# train loss is -1.0278
# valid loss is -0.7110
#
# Epoch 170/499
# ----------
# train loss is -1.0724
# valid loss is -0.6410
#
# Epoch 171/499
# ----------
# train loss is -1.0885
# valid loss is -0.5891
#
# Epoch 172/499
# ----------
# train loss is -1.0845
# valid loss is -0.8179
#
# Epoch 173/499
# ----------
# train loss is -1.0856
# valid loss is -0.8888
#
# Epoch 174/499
# ----------
# train loss is -1.1089
# valid loss is -0.6216
#
# Epoch 175/499
# ----------
# train loss is -1.1062
# valid loss is -0.8571
#
# Epoch 176/499
# ----------
# train loss is -1.1037
# valid loss is -0.0638
#
# Epoch 177/499
# ----------
# train loss is -1.0810
# valid loss is -0.5890
#
# Epoch 178/499
# ----------
# train loss is -1.0974
# valid loss is -0.8833
#
# Epoch 179/499
# ----------
# train loss is -1.0570
# valid loss is -0.5118
#
# Epoch 180/499
# ----------
# train loss is -1.0778
# valid loss is -0.6744
#
# Epoch 181/499
# ----------
# train loss is -1.1040
# valid loss is -0.6572
#
# Epoch 182/499
# ----------
# train loss is -1.0961
# valid loss is -1.0787
#
# Epoch 183/499
# ----------
# train loss is -1.0536
# valid loss is -0.6020
#
# Epoch 184/499
# ----------
# train loss is -1.1135
# valid loss is -0.8698
#
# Epoch 185/499
# ----------
# train loss is -1.1342
# valid loss is -0.3750
#
# Epoch 186/499
# ----------
# train loss is -1.1179
# valid loss is -0.8691
#
# Epoch 187/499
# ----------
# train loss is -1.1190
# valid loss is -0.8824
#
# Epoch 188/499
# ----------
# train loss is -1.1219
# valid loss is -0.5020
#
# Epoch 189/499
# ----------
# train loss is -1.1522
# valid loss is -0.7811
#
# Epoch 190/499
# ----------
# train loss is -1.1392
# valid loss is -0.5189
#
# Epoch 191/499
# ----------
# train loss is -1.1572
# valid loss is -0.0373
#
# Epoch 192/499
# ----------
# train loss is -1.1515
# valid loss is -0.3091
#
# Epoch 193/499
# ----------
# train loss is -1.1337
# valid loss is 1.0854
#
# Epoch 194/499
# ----------
# train loss is -1.1189
# valid loss is -0.9194
#
# Epoch 195/499
# ----------
# train loss is -1.1532
# valid loss is 0.5282
#
# Epoch 196/499
# ----------
# train loss is -1.1208
# valid loss is -0.8983
#
# Epoch 197/499
# ----------
# train loss is -1.1649
# valid loss is -0.4320
#
# Epoch 198/499
# ----------
# train loss is -1.1861
# valid loss is -0.4868
#
# Epoch 199/499
# ----------
# train loss is -1.1787
# valid loss is 0.6943
#
# Epoch 200/499
# ----------
# train loss is -1.1689
# valid loss is -0.2134
#
# Epoch 201/499
# ----------
# train loss is -1.1748
# valid loss is 0.7638
#
# Epoch 202/499
# ----------
# train loss is -1.1792
# valid loss is 0.4598
#
# Epoch 203/499
# ----------
# train loss is -1.1694
# valid loss is -0.8103
#
# Epoch 204/499
# ----------
# train loss is -1.1565
# valid loss is 1.5813
#
# Epoch 205/499
# ----------
# train loss is -1.1133
# valid loss is 0.3737
#
# Epoch 206/499
# ----------
# train loss is -1.1725
# valid loss is 0.1280
#
# Epoch 207/499
# ----------
# train loss is -1.1966
# valid loss is 0.8055
#
# Epoch 208/499
# ----------
# train loss is -1.1882
# valid loss is 0.3515
#
# Epoch 209/499
# ----------
# train loss is -1.1876
# valid loss is -0.8299
#
# Epoch 210/499
# ----------
# train loss is -1.0972
# valid loss is 0.0989
#
# Epoch 211/499
# ----------
# train loss is -1.1519
# valid loss is -0.1435
#
# Epoch 212/499
# ----------
# train loss is -1.2020
# valid loss is 1.1094
#
# Epoch 213/499
# ----------
# train loss is -1.1439
# valid loss is 2.0376
#
# Epoch 214/499
# ----------
# train loss is -1.1788
# valid loss is -0.5221
#
# Epoch 215/499
# ----------
# train loss is -1.1946
# valid loss is -0.5631
#
# Epoch 216/499
# ----------
# train loss is -1.2091
# valid loss is 1.2507
#
# Epoch 217/499
# ----------
# train loss is -1.2349
# valid loss is 1.3406
#
# Epoch 218/499
# ----------
# train loss is -1.2529
# valid loss is 2.1331
#
# Epoch 219/499
# ----------
# train loss is -1.2582
# valid loss is 1.1529
#
# Epoch 220/499
# ----------
# train loss is -1.2640
# valid loss is 1.2883
#
# Epoch 221/499
# ----------
# train loss is -1.2493
# valid loss is 0.3602
#
# Epoch 222/499
# ----------
# train loss is -1.1297
# valid loss is 0.7372
#
# Epoch 223/499
# ----------
# train loss is -1.1349
# valid loss is -0.6542
#
# Epoch 224/499
# ----------
# train loss is -1.1093
# valid loss is 1.5415
#
# Epoch 225/499
# ----------
# train loss is -1.1681
# valid loss is -0.8808
#
# Epoch 226/499
# ----------
# train loss is -1.2287
# valid loss is 1.5945
#
# Epoch 227/499
# ----------
# train loss is -1.2277
# valid loss is 4.7136
#
# Epoch 228/499
# ----------
# train loss is -1.2258
# valid loss is 1.0944
#
# Epoch 229/499
# ----------
# train loss is -1.2496
# valid loss is 4.1673
#
# Epoch 230/499
# ----------
# train loss is -1.2333
# valid loss is 0.0270
#
# Epoch 231/499
# ----------
# train loss is -1.2734
# valid loss is 1.9693
#
# Epoch 232/499
# ----------
# train loss is -1.2962
# valid loss is 0.7175
#
# Epoch 233/499
# ----------
# train loss is -1.2408
# valid loss is 0.5578
#
# Epoch 234/499
# ----------
# train loss is -1.1586
# valid loss is 2.7240
#
# Epoch 235/499
# ----------
# train loss is -1.1873
# valid loss is -0.9062
#
# Epoch 236/499
# ----------
# train loss is -1.2279
# valid loss is 0.5187
#
# Epoch 237/499
# ----------
# train loss is -1.2906
# valid loss is 0.5436
#
# Epoch 238/499
# ----------
# train loss is -1.2066
# valid loss is 1.5019
#
# Epoch 239/499
# ----------
# train loss is -1.2728
# valid loss is 3.1968
#
# Epoch 240/499
# ----------
# train loss is -1.2332
# valid loss is 0.4111
#
# Epoch 241/499
# ----------
# train loss is -1.2959
# valid loss is 1.6930
#
# Epoch 242/499
# ----------
# train loss is -1.3294
# valid loss is 2.0412
#
# Epoch 243/499
# ----------
# train loss is -1.2886
# valid loss is 2.4667
#
# Epoch 244/499
# ----------
# train loss is -1.2975
# valid loss is 3.2634
#
# Epoch 245/499
# ----------
# train loss is -1.2160
# valid loss is 1.8038
#
# Epoch 246/499
# ----------
# train loss is -1.2239
# valid loss is 1.0315
#
# Epoch 247/499
# ----------
# train loss is -1.2652
# valid loss is -0.1106
#
# Epoch 248/499
# ----------
# train loss is -1.2930
# valid loss is 6.1467
#
# Epoch 249/499
# ----------
# train loss is -1.2205
# valid loss is -0.0554
#
# Epoch 250/499
# ----------
# train loss is -1.2838
# valid loss is 0.1409
#
# Epoch 251/499
# ----------
# train loss is -1.2921
# valid loss is 2.1438
#
# Epoch 252/499
# ----------
# train loss is -1.3421
# valid loss is 2.1801
#
# Epoch 253/499
# ----------
# train loss is -1.3124
# valid loss is 0.7560
#
# Epoch 254/499
# ----------
# train loss is -1.3164
# valid loss is 4.1130
#
# Epoch 255/499
# ----------
# train loss is -1.3009
# valid loss is 3.4172
#
# Epoch 256/499
# ----------
# train loss is -1.3276
# valid loss is 1.5635
#
# Epoch 257/499
# ----------
# train loss is -1.3489
# valid loss is 3.7586
#
# Epoch 258/499
# ----------
# train loss is -1.3864
# valid loss is 1.9812
#
# Epoch 259/499
# ----------
# train loss is -1.3163
# valid loss is 1.5180
#
# Epoch 260/499
# ----------
# train loss is -1.3007
# valid loss is 1.9264
#
# Epoch 261/499
# ----------
# train loss is -1.2840
# valid loss is 1.3082
#
# Epoch 262/499
# ----------
# train loss is -1.3344
# valid loss is 1.0715
#
# Epoch 263/499
# ----------
# train loss is -1.3711
# valid loss is 4.4986
#
# Epoch 264/499
# ----------
# train loss is -1.3657
# valid loss is 4.0176
#
# Epoch 265/499
# ----------
# train loss is -1.3687
# valid loss is 2.3086
#
# Epoch 266/499
# ----------
# train loss is -1.3918
# valid loss is 2.3884
#
# Epoch 267/499
# ----------
# train loss is -1.3938
# valid loss is 5.0008
#
# Epoch 268/499
# ----------
# train loss is -1.3877
# valid loss is 4.1351
#
# Epoch 269/499
# ----------
# train loss is -1.3928
# valid loss is 3.0920
#
# Epoch 270/499
# ----------
# train loss is -1.3838
# valid loss is 3.1762
#
# Epoch 271/499
# ----------
# train loss is -1.3376
# valid loss is 6.5328
#
# Epoch 272/499
# ----------
# train loss is -1.3333
# valid loss is 2.6524
#
# Epoch 273/499
# ----------
# train loss is -1.3855
# valid loss is 3.3231
#
# Epoch 274/499
# ----------
# train loss is -1.3925
# valid loss is 4.8401
#
# Epoch 275/499
# ----------
# train loss is -1.3900
# valid loss is 5.3378
#
# Epoch 276/499
# ----------
# train loss is -1.3862
# valid loss is 3.7634
#
# Epoch 277/499
# ----------
# train loss is -1.3982
# valid loss is 1.4065
#
# Epoch 278/499
# ----------
# train loss is -1.2740
# valid loss is 2.8340
#
# Epoch 279/499
# ----------
# train loss is -1.3663
# valid loss is 4.4067
#
# Epoch 280/499
# ----------
# train loss is -1.3719
# valid loss is 3.9043
#
# Epoch 281/499
# ----------
# train loss is -1.4110
# valid loss is 5.3642
#
# Epoch 282/499
# ----------
# train loss is -1.4170
# valid loss is 7.8930
#
# Epoch 283/499
# ----------
# train loss is -1.4327
# valid loss is 3.5537
#
# Epoch 284/499
# ----------
# train loss is -1.4239
# valid loss is 3.9241
#
# Epoch 285/499
# ----------
# train loss is -1.3477
# valid loss is 2.4101
#
# Epoch 286/499
# ----------
# train loss is -1.3932
# valid loss is 3.8397
#
# Epoch 287/499
# ----------
# train loss is -1.3741
# valid loss is 6.2064
#
# Epoch 288/499
# ----------
# train loss is -1.3469
# valid loss is 1.8927
#
# Epoch 289/499
# ----------
# train loss is -1.3742
# valid loss is 4.2279
#
# Epoch 290/499
# ----------
# train loss is -1.3851
# valid loss is 3.0622
#
# Epoch 291/499
# ----------
# train loss is -1.4197
# valid loss is 2.2695
#
# Epoch 292/499
# ----------
# train loss is -1.4136
# valid loss is 7.5582
#
# Epoch 293/499
# ----------
# train loss is -1.3729
# valid loss is 3.3775
#
# Epoch 294/499
# ----------
# train loss is -1.4422
# valid loss is 3.9447
#
# Epoch 295/499
# ----------
# train loss is -1.4520
# valid loss is 6.8665
#
# Epoch 296/499
# ----------
# train loss is -1.4331
# valid loss is 3.1128
#
# Epoch 297/499
# ----------
# train loss is -1.3500
# valid loss is 2.1420
#
# Epoch 298/499
# ----------
# train loss is -1.2120
# valid loss is 2.7266
#
# Epoch 299/499
# ----------
# train loss is -1.2413
# valid loss is 3.7060
#
# Epoch 300/499
# ----------
# train loss is -1.2961
# valid loss is 1.5729
#
# Epoch 301/499
# ----------
# train loss is -1.3112
# valid loss is 1.6164
#
# Epoch 302/499
# ----------
# train loss is -1.4070
# valid loss is 2.8606
#
# Epoch 303/499
# ----------
# train loss is -1.3946
# valid loss is 8.2258
#
# Epoch 304/499
# ----------
# train loss is -1.3937
# valid loss is 2.4331
#
# Epoch 305/499
# ----------
# train loss is -1.4191
# valid loss is 4.3228
#
# Epoch 306/499
# ----------
# train loss is -1.4278
# valid loss is 4.6239
#
# Epoch 307/499
# ----------
# train loss is -1.4437
# valid loss is 2.1081
#
# Epoch 308/499
# ----------
# train loss is -1.3775
# valid loss is 3.8370
#
# Epoch 309/499
# ----------
# train loss is -1.4220
# valid loss is 5.8391
#
# Epoch 310/499
# ----------
# train loss is -1.3745
# valid loss is 2.1927
#
# Epoch 311/499
# ----------
# train loss is -1.4485
# valid loss is 3.2109
#
# Epoch 312/499
# ----------
# train loss is -1.4638
# valid loss is 4.7177
#
# Epoch 313/499
# ----------
# train loss is -1.4624
# valid loss is 4.8250
#
# Epoch 314/499
# ----------
# train loss is -1.4698
# valid loss is 4.9980
#
# Epoch 315/499
# ----------
# train loss is -1.4200
# valid loss is 2.8677
#
# Epoch 316/499
# ----------
# train loss is -1.4623
# valid loss is 4.4167
#
# Epoch 317/499
# ----------
# train loss is -1.4755
# valid loss is 5.3480
#
# Epoch 318/499
# ----------
# train loss is -1.4131
# valid loss is 2.8528
#
# Epoch 319/499
# ----------
# train loss is -1.4521
# valid loss is 2.9649
#
# Epoch 320/499
# ----------
# train loss is -1.4583
# valid loss is 5.5263
#
# Epoch 321/499
# ----------
# train loss is -1.4704
# valid loss is 4.4532
#
# Epoch 322/499
# ----------
# train loss is -1.4546
# valid loss is 2.2761
#
# Epoch 323/499
# ----------
# train loss is -1.4406
# valid loss is 4.7673
#
# Epoch 324/499
# ----------
# train loss is -1.4586
# valid loss is 2.8657
#
# Epoch 325/499
# ----------
# train loss is -1.4225
# valid loss is 6.8666
#
# Epoch 326/499
# ----------
# train loss is -1.4044
# valid loss is 2.9339
#
# Epoch 327/499
# ----------
# train loss is -1.4632
# valid loss is 2.6673
#
# Epoch 328/499
# ----------
# train loss is -1.4505
# valid loss is 4.3436
#
# Epoch 329/499
# ----------
# train loss is -1.4810
# valid loss is 3.2054
#
# Epoch 330/499
# ----------
# train loss is -1.4551
# valid loss is 4.7255
#
# Epoch 331/499
# ----------
# train loss is -1.3460
# valid loss is 3.5624
#
# Epoch 332/499
# ----------
# train loss is -1.4024
# valid loss is 1.1324
#
# Epoch 333/499
# ----------
# train loss is -1.4503
# valid loss is 3.5052
#
# Epoch 334/499
# ----------
# train loss is -1.4291
# valid loss is 3.2308
#
# Epoch 335/499
# ----------
# train loss is -1.4136
# valid loss is 4.9376
#
# Epoch 336/499
# ----------
# train loss is -1.4052
# valid loss is 1.5048
#
# Epoch 337/499
# ----------
# train loss is -1.4429
# valid loss is 4.6446
#
# Epoch 338/499
# ----------
# train loss is -1.4155
# valid loss is 1.9916
#
# Epoch 339/499
# ----------
# train loss is -1.4345
# valid loss is 2.6823
#
# Epoch 340/499
# ----------
# train loss is -1.4396
# valid loss is 4.1773
#
# Epoch 341/499
# ----------
# train loss is -1.3934
# valid loss is 2.2797
#
# Epoch 342/499
# ----------
# train loss is -1.4774
# valid loss is 2.3542
#
# Epoch 343/499
# ----------
# train loss is -1.4918
# valid loss is 4.4821
#
# Epoch 344/499
# ----------
# train loss is -1.4585
# valid loss is 4.4886
#
# Epoch 345/499
# ----------
# train loss is -1.4602
# valid loss is 2.0345
#
# Epoch 346/499
# ----------
# train loss is -1.3957
# valid loss is 3.3035
#
# Epoch 347/499
# ----------
# train loss is -1.4071
# valid loss is 1.8724
#
# Epoch 348/499
# ----------
# train loss is -1.4253
# valid loss is 2.1038
#
# Epoch 349/499
# ----------
# train loss is -1.4796
# valid loss is 3.6589
#
# Epoch 350/499
# ----------
# train loss is -1.4825
# valid loss is 4.1509
#
# Epoch 351/499
# ----------
# train loss is -1.4699
# valid loss is 3.9933
#
# Epoch 352/499
# ----------
# train loss is -1.4529
# valid loss is 3.7724
#
# Epoch 353/499
# ----------
# train loss is -1.4685
# valid loss is 3.4396
#
# Epoch 354/499
# ----------
# train loss is -1.4184
# valid loss is 1.6180
#
# Epoch 355/499
# ----------
# train loss is -1.4771
# valid loss is 3.6570
#
# Epoch 356/499
# ----------
# train loss is -1.5011
# valid loss is 3.5158
#
# Epoch 357/499
# ----------
# train loss is -1.4868
# valid loss is 4.4237
#
# Epoch 358/499
# ----------
# train loss is -1.4701
# valid loss is 3.7302
#
# Epoch 359/499
# ----------
# train loss is -1.4981
# valid loss is 3.0717
#
# Epoch 360/499
# ----------
# train loss is -1.5124
# valid loss is 4.7380
#
# Epoch 361/499
# ----------
# train loss is -1.5095
# valid loss is 3.0127
#
# Epoch 362/499
# ----------
# train loss is -1.5006
# valid loss is 3.0316
#
# Epoch 363/499
# ----------
# train loss is -1.4867
# valid loss is 5.1158
#
# Epoch 364/499
# ----------
# train loss is -1.4815
# valid loss is 1.7179
#
# Epoch 365/499
# ----------
# train loss is -1.4664
# valid loss is 3.4210
#
# Epoch 366/499
# ----------
# train loss is -1.4885
# valid loss is 5.3716
#
# Epoch 367/499
# ----------
# train loss is -1.3319
# valid loss is 1.1628
#
# Epoch 368/499
# ----------
# train loss is -1.4122
# valid loss is 1.7480
#
# Epoch 369/499
# ----------
# train loss is -1.4147
# valid loss is 1.5665
#
# Epoch 370/499
# ----------
# train loss is -1.4525
# valid loss is 2.6301
#
# Epoch 371/499
# ----------
# train loss is -1.4735
# valid loss is 1.5939
#
# Epoch 372/499
# ----------
# train loss is -1.4811
# valid loss is 2.6859
#
# Epoch 373/499
# ----------
# train loss is -1.5173
# valid loss is 3.3290
#
# Epoch 374/499
# ----------
# train loss is -1.5044
# valid loss is 2.1834
#
# Epoch 375/499
# ----------
# train loss is -1.3725
# valid loss is 2.1688
#
# Epoch 376/499
# ----------
# train loss is -1.4500
# valid loss is 1.0603
#
# Epoch 377/499
# ----------
# train loss is -1.4739
# valid loss is 0.9869
#
# Epoch 378/499
# ----------
# train loss is -1.4853
# valid loss is 2.9980
#
# Epoch 379/499
# ----------
# train loss is -1.4980
# valid loss is 3.0294
#
# Epoch 380/499
# ----------
# train loss is -1.4848
# valid loss is 2.4086
#
# Epoch 381/499
# ----------
# train loss is -1.4993
# valid loss is 3.1010
#
# Epoch 382/499
# ----------
# train loss is -1.4965
# valid loss is 1.6419
#
# Epoch 383/499
# ----------
# train loss is -1.5112
# valid loss is 3.0706
#
# Epoch 384/499
# ----------
# train loss is -1.5128
# valid loss is 3.1356
#
# Epoch 385/499
# ----------
# train loss is -1.5188
# valid loss is 3.2620
#
# Epoch 386/499
# ----------
# train loss is -1.5222
# valid loss is 2.4886
#
# Epoch 387/499
# ----------
# train loss is -1.4973
# valid loss is 2.8804
#
# Epoch 388/499
# ----------
# train loss is -1.4075
# valid loss is 2.7165
#
# Epoch 389/499
# ----------
# train loss is -1.4616
# valid loss is 0.4955
#
# Epoch 390/499
# ----------
# train loss is -1.4603
# valid loss is 1.6939
#
# Epoch 391/499
# ----------
# train loss is -1.4393
# valid loss is 1.9929
#
# Epoch 392/499
# ----------
# train loss is -1.4513
# valid loss is 2.5001
#
# Epoch 393/499
# ----------
# train loss is -1.4953
# valid loss is 1.7965
#
# Epoch 394/499
# ----------
# train loss is -1.5202
# valid loss is 3.0411
#
# Epoch 395/499
# ----------
# train loss is -1.5040
# valid loss is 2.5506
#
# Epoch 396/499
# ----------
# train loss is -1.4138
# valid loss is 2.3552
#
# Epoch 397/499
# ----------
# train loss is -1.4941
# valid loss is 0.6873
#
# Epoch 398/499
# ----------
# train loss is -1.4937
# valid loss is 2.9763
#
# Epoch 399/499
# ----------
# train loss is -1.5114
# valid loss is 2.5403
#
# Epoch 400/499
# ----------
# train loss is -1.5127
# valid loss is 3.2394
#
# Epoch 401/499
# ----------
# train loss is -1.5416
# valid loss is 3.6814
#
# Epoch 402/499
# ----------
# train loss is -1.5092
# valid loss is 2.4767
#
# Epoch 403/499
# ----------
# train loss is -1.5412
# valid loss is 2.4641
#
# Epoch 404/499
# ----------
# train loss is -1.5404
# valid loss is 2.8839
#
# Epoch 405/499
# ----------
# train loss is -1.4836
# valid loss is 4.9855
#
# Epoch 406/499
# ----------
# train loss is -1.4676
# valid loss is 0.3893
#
# Epoch 407/499
# ----------
# train loss is -1.4069
# valid loss is 1.9294
#
# Epoch 408/499
# ----------
# train loss is -1.4978
# valid loss is 1.1155
#
# Epoch 409/499
# ----------
# train loss is -1.5307
# valid loss is 2.7544
#
# Epoch 410/499
# ----------
# train loss is -1.5122
# valid loss is 2.8324
#
# Epoch 411/499
# ----------
# train loss is -1.5181
# valid loss is 1.9945
#
# Epoch 412/499
# ----------
# train loss is -1.4876
# valid loss is 1.5813
#
# Epoch 413/499
# ----------
# train loss is -1.4860
# valid loss is 1.8316
#
# Epoch 414/499
# ----------
# train loss is -1.5402
# valid loss is 2.3726
#
# Epoch 415/499
# ----------
# train loss is -1.5246
# valid loss is 3.4467
#
# Epoch 416/499
# ----------
# train loss is -1.5066
# valid loss is 2.2481
#
# Epoch 417/499
# ----------
# train loss is -1.4957
# valid loss is 1.7676
#
# Epoch 418/499
# ----------
# train loss is -1.4797
# valid loss is 3.1674
#
# Epoch 419/499
# ----------
# train loss is -1.4686
# valid loss is 0.6489
#
# Epoch 420/499
# ----------
# train loss is -1.4978
# valid loss is 3.1693
#
# Epoch 421/499
# ----------
# train loss is -1.5089
# valid loss is 1.4393
#
# Epoch 422/499
# ----------
# train loss is -1.4721
# valid loss is 1.5941
#
# Epoch 423/499
# ----------
# train loss is -1.5000
# valid loss is 2.7190
#
# Epoch 424/499
# ----------
# train loss is -1.4960
# valid loss is 1.0672
#
# Epoch 425/499
# ----------
# train loss is -1.5221
# valid loss is 1.8630
#
# Epoch 426/499
# ----------
# train loss is -1.5283
# valid loss is 3.5357
#
# Epoch 427/499
# ----------
# train loss is -1.5166
# valid loss is 2.0614
#
# Epoch 428/499
# ----------
# train loss is -1.5203
# valid loss is 2.7515
#
# Epoch 429/499
# ----------
# train loss is -1.4914
# valid loss is 2.5787
#
# Epoch 430/499
# ----------
# train loss is -1.5088
# valid loss is 1.7999
#
# Epoch 431/499
# ----------
# train loss is -1.5400
# valid loss is 2.6235
#
# Epoch 432/499
# ----------
# train loss is -1.5179
# valid loss is 3.4207
#
# Epoch 433/499
# ----------
# train loss is -1.4973
# valid loss is 2.5888
#
# Epoch 434/499
# ----------
# train loss is -1.4800
# valid loss is 1.0143
#
# Epoch 435/499
# ----------
# train loss is -1.4955
# valid loss is 2.0697
#
# Epoch 436/499
# ----------
# train loss is -1.4960
# valid loss is 1.8986
#
# Epoch 437/499
# ----------
# train loss is -1.5222
# valid loss is 1.8026
#
# Epoch 438/499
# ----------
# train loss is -1.5158
# valid loss is 1.9587
#
# Epoch 439/499
# ----------
# train loss is -1.4865
# valid loss is 3.5211
#
# Epoch 440/499
# ----------
# train loss is -1.4217
# valid loss is 0.6192
#
# Epoch 441/499
# ----------
# train loss is -1.4670
# valid loss is 1.5937
#
# Epoch 442/499
# ----------
# train loss is -1.4911
# valid loss is 2.5583
#
# Epoch 443/499
# ----------
# train loss is -1.4824
# valid loss is 1.4527
#
# Epoch 444/499
# ----------
# train loss is -1.5464
# valid loss is 2.0136
#
# Epoch 445/499
# ----------
# train loss is -1.5384
# valid loss is 2.6908
#
# Epoch 446/499
# ----------
# train loss is -1.5431
# valid loss is 2.4373
#
# Epoch 447/499
# ----------
# train loss is -1.5210
# valid loss is 2.1780
#
# Epoch 448/499
# ----------
# train loss is -1.5242
# valid loss is 1.4950
#
# Epoch 449/499
# ----------
# train loss is -1.5087
# valid loss is 1.9406
#
# Epoch 450/499
# ----------
# train loss is -1.5351
# valid loss is 2.4624
#
# Epoch 451/499
# ----------
# train loss is -1.5326
# valid loss is 1.7020
#
# Epoch 452/499
# ----------
# train loss is -1.5151
# valid loss is 1.8044
#
# Epoch 453/499
# ----------
# train loss is -1.4743
# valid loss is 2.4606
#
# Epoch 454/499
# ----------
# train loss is -1.4540
# valid loss is 0.5581
#
# Epoch 455/499
# ----------
# train loss is -1.5026
# valid loss is 1.3216
#
# Epoch 456/499
# ----------
# train loss is -1.5353
# valid loss is 2.3257
#
# Epoch 457/499
# ----------
# train loss is -1.5279
# valid loss is 2.7984
#
# Epoch 458/499
# ----------
# train loss is -1.5181
# valid loss is 2.1062
#
# Epoch 459/499
# ----------
# train loss is -1.5412
# valid loss is 1.1314
#
# Epoch 460/499
# ----------
# train loss is -1.5135
# valid loss is 1.9364
#
# Epoch 461/499
# ----------
# train loss is -1.4524
# valid loss is 1.2801
#
# Epoch 462/499
# ----------
# train loss is -1.4829
# valid loss is 1.1341
#
# Epoch 463/499
# ----------
# train loss is -1.5337
# valid loss is 0.9313
#
# Epoch 464/499
# ----------
# train loss is -1.4785
# valid loss is 2.6988
#
# Epoch 465/499
# ----------
# train loss is -1.4497
# valid loss is 0.8804
#
# Epoch 466/499
# ----------
# train loss is -1.4912
# valid loss is 1.2101
#
# Epoch 467/499
# ----------
# train loss is -1.4985
# valid loss is 1.3600
#
# Epoch 468/499
# ----------
# train loss is -1.5159
# valid loss is 1.0959
#
# Epoch 469/499
# ----------
# train loss is -1.5231
# valid loss is 2.3766
#
# Epoch 470/499
# ----------
# train loss is -1.5426
# valid loss is 1.5666
#
# Epoch 471/499
# ----------
# train loss is -1.5406
# valid loss is 1.9628
#
# Epoch 472/499
# ----------
# train loss is -1.5494
# valid loss is 1.7896
#
# Epoch 473/499
# ----------
# train loss is -1.5476
# valid loss is 2.5285
#
# Epoch 474/499
# ----------
# train loss is -1.5293
# valid loss is 1.5835
#
# Epoch 475/499
# ----------
# train loss is -1.5395
# valid loss is 1.7619
#
# Epoch 476/499
# ----------
# train loss is -1.5162
# valid loss is 1.5987
#
# Epoch 477/499
# ----------
# train loss is -1.5483
# valid loss is 1.7827
#
# Epoch 478/499
# ----------
# train loss is -1.5350
# valid loss is 1.4088
#
# Epoch 479/499
# ----------
# train loss is -1.5499
# valid loss is 2.3002
#
# Epoch 480/499
# ----------
# train loss is -1.5584
# valid loss is 1.6384
#
# Epoch 481/499
# ----------
# train loss is -1.5485
# valid loss is 1.8632
#
# Epoch 482/499
# ----------
# train loss is -1.5335
# valid loss is 2.8080
#
# Epoch 483/499
# ----------
# train loss is -1.5318
# valid loss is 1.6370
#
# Epoch 484/499
# ----------
# train loss is -1.5134
# valid loss is 0.7871
#
# Epoch 485/499
# ----------
# train loss is -1.4780
# valid loss is 1.5061
#
# Epoch 486/499
# ----------
# train loss is -1.5099
# valid loss is 0.6595
#
# Epoch 487/499
# ----------
# train loss is -1.5097
# valid loss is 1.5213
#
# Epoch 488/499
# ----------
# train loss is -1.5290
# valid loss is 1.6719
#
# Epoch 489/499
# ----------
# train loss is -1.5667
# valid loss is 1.4224
#
# Epoch 490/499
# ----------
# train loss is -1.5483
# valid loss is 2.5599
#
# Epoch 491/499
# ----------
# train loss is -1.5398
# valid loss is 1.2605
#
# Epoch 492/499
# ----------
# train loss is -1.5465
# valid loss is 1.9339
#
# Epoch 493/499
# ----------
# train loss is -1.5267
# valid loss is 1.9790
#
# Epoch 494/499
# ----------
# train loss is -1.5552
# valid loss is 1.0690
#
# Epoch 495/499
# ----------
# train loss is -1.5161
# valid loss is 1.8362
#
# Epoch 496/499
# ----------
# train loss is -1.5009
# valid loss is 0.8154
#
# Epoch 497/499
# ----------
# train loss is -1.5589
# valid loss is 0.9387
#
# Epoch 498/499
# ----------
# train loss is -1.5514
# valid loss is 2.2103
#
# Epoch 499/499
# ----------
# train loss is -1.5542
# valid loss is 1.5774
#
# Training complete in 0m 8s
# Best loss: -1.302811
# LinearDensityNN(
#   (fc1): Linear(in_features=1, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=50, bias=True)
#   (fc3_1): Linear(in_features=50, out_features=1, bias=True)
#   (fc3_2): Linear(in_features=50, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.0, inplace=False)
#   (dropout2): Dropout(p=0.0, inplace=False)
# )

# %%
model.eval()
y_pred, y_sigma = model(torch.from_numpy(x_data).float())#
y_pred = y_pred.detach().numpy()
y_sigma = y_sigma.detach().numpy()

# %%
plt.figure(figsize=(12,6))
plt.axis([-8,8,-2.0,2.0])
plt.plot(x_data,y_data,label='True',color='k')
plt.plot(x_train,y_train,'r.',label='train')
plt.plot(x_data,y_pred,'b',label='pred')
plt.fill_between(x_data[:,0],y_pred[:,0]+y_sigma[:,0],
                 y_pred[:,0]-y_sigma[:,0],color='b',alpha=.25,label='1 sigma')
plot_vline()
plt.grid(True)
plt.legend(fontsize=16)
plt.title('Training Data for a Regression Task',fontsize=16)

plt.figure(figsize=(12,6))
plt.axis([-8,8,0.0,1.0])
plt.plot(x_data,y_sigma,'b',label='pred')
